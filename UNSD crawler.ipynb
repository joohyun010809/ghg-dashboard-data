# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting selenium
#   Downloading selenium-4.29.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2024.7.4)
# Requirement already satisfied: typing_extensions~=4.9 in c:\programdata\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.29.0-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --------------- ------------------------ 3.8/9.5 MB 80.8 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.5 MB 70.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 65.9 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 68.0 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 68.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 40.7 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ---------------------------------------- 0.0/492.9 kB ? eta -:--:--
#    --------------------------------------- 492.9/492.9 kB 32.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.8 kB ? eta -:--:--
#    ---------------------------------------- 63.8/63.8 kB 3.3 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
# Successfully installed attrs-25.3.0 outcome-1.3.0.post0 selenium-4.29.0 trio-0.29.0 trio-websocket-0.12.2 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# pip install -r requirements.txt

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException
import os
import time
import glob

# --- [1] 설정: 크롬 드라이버 경로 및 다운로드 폴더 ---
driver_path = r'C:\Users\박주현\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe'
download_dir = r'C:\Users\박주현\Downloads'  # 크롬 다운로드 기본 경로
save_dir = r'C:\Users\박주현\Documents\UNSD total ghg data'

# --- [2] Selenium 옵션 설정 ---
options = Options()
options.headless = False  # 브라우저 보이게 설정
prefs = {'download.default_directory': download_dir}
options.add_experimental_option('prefs', prefs)

# --- [3] 웹 드라이버 실행 ---
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)
driver.get('https://di.unfccc.int/detailed_data_by_party')
time.sleep(3)

# --- [4] 첫 번째 드롭다운: 국가 목록 가져오기 ---
select1 = Select(driver.find_element(By.XPATH, '/html/body/div/div/div[2]/div/div/select[1]'))
first_dropdown_options = [option.text for option in select1.options if option.text != '--Select Party--']

# --- [5] 국가별 반복 시작 ---
for first_option in first_dropdown_options:
    print(f"\n🌐 국가 처리 중: {first_option}")
    try:
        select1.select_by_visible_text(first_option)
        time.sleep(2)

        # --- [6] 세 번째 드롭다운 옵션 확인 ---
        select3_element = WebDriverWait(driver, 15).until(
            EC.presence_of_element_located((By.XPATH, '/html/body/div/div/div[2]/div/div/select[3]'))
        )
        select3 = Select(select3_element)
        third_options = [opt.text.strip() for opt in select3.options]

        # --- [7] 사용할 GHG 옵션 필터링 ---
        target_third_options = [
            "....Total GHG emissions excluding LULUCF/LUCF",
            "....Total GHG emissions without LULUCF"
        ]
        matched_third = [opt for opt in third_options if opt in target_third_options]

        if not matched_third:
            print("❌ 사용 가능한 GHG 옵션이 없음. 건너뜀")
            continue

        # --- [8] 세 번째 옵션 순회 ---
        for third_option in matched_third:
            print(f"➡ 세 번째 옵션: {third_option}")
            select3.select_by_visible_text(third_option)
            time.sleep(1)

            # --- [9] 나머지 드롭다운 설정 (2, 4, 5번째) ---
            Select(driver.find_element(By.XPATH, '/html/body/div/div/div[2]/div/div/select[2]')).select_by_visible_text('All years')
            Select(driver.find_element(By.XPATH, '/html/body/div/div/div[2]/div/div/select[4]')).select_by_visible_text('Aggregate GHGs')

            # 다섯 번째 옵션 자동 판단
            select5 = Select(driver.find_element(By.XPATH, '/html/body/div/div/div[2]/div/div/select[5]'))
            fifth_options = [opt.text.strip() for opt in select5.options]

            if "Tg CO₂ equivalent" in fifth_options:
                selected_unit = "Tg CO2e"
                select5.select_by_visible_text("Tg CO₂ equivalent")
            elif "Mt CO₂ equivalent" in fifth_options:
                selected_unit = "Mt CO2e"
                select5.select_by_visible_text("Mt CO₂ equivalent")
            else:
                print("❌ 단위 선택 실패")
                continue

            # --- [10] 다운로드 버튼 클릭 ---
            try:
                download_button = WebDriverWait(driver, 20).until(
                    EC.element_to_be_clickable((By.XPATH, '//button[contains(@class, "dt-button") and contains(@class, "buttons-excel")]//span[text()="Export to Excel"]'))
                )
                download_button.click()
                print("⬇️ 다운로드 시도")
                time.sleep(5)
            except TimeoutException:
                print("❌ 다운로드 버튼 클릭 실패")
                continue

            # --- [11] 최신 파일 이름으로 저장 ---
            try:
                label = driver.find_element(By.CLASS_NAME, 'gray').text.strip()
                safe_name = f"{first_option}_{third_option.replace('.', '').strip()}_{selected_unit}.xlsx".replace('/', '_').replace('\\', '_')

                list_of_files = glob.glob(os.path.join(download_dir, '*.xlsx'))
                if not list_of_files:
                    print("❌ 다운로드된 파일 없음")
                    continue
                latest_file = max(list_of_files, key=os.path.getctime)

                dest_path = os.path.join(save_dir, safe_name)
                os.rename(latest_file, dest_path)
                print(f"📁 저장 완료: {dest_path}")
            except Exception as e:
                print(f"❌ 파일 저장 실패: {e}")

    except Exception as e:
        print(f"❌ 국가 처리 중 오류: {e}")
        continue

# --- [12] 마무리 ---
driver.quit()
print("\n✅ 크롤링 완료")
# Out:
# 🌐 국가 처리 중: Annex I
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Annex I_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Annex I EIT
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Annex I EIT_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Annex I non-EIT
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Annex I non-EIT_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Australia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Australia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Austria
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Austria_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Belarus
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Belarus_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Belgium
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Belgium_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Bulgaria
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bulgaria_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Canada
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Canada_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Croatia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Croatia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Cyprus
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cyprus_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Czechia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Czechia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Denmark
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Denmark_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Estonia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Estonia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: European Union (Convention)
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\European Union (Convention)_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Finland
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Finland_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: France
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\France_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Germany
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Germany_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Greece
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Greece_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Hungary
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Hungary_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Iceland
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Iceland_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Ireland
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Ireland_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Italy
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Italy_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Japan
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Japan_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Kazakhstan
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Kazakhstan_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Latvia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Latvia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Liechtenstein
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Liechtenstein_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Lithuania
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Lithuania_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Luxembourg
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Luxembourg_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Malta
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Malta_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Monaco
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Monaco_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Netherlands
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Netherlands_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: New Zealand
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\New Zealand_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Norway
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Norway_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Poland
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Poland_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Portugal
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Portugal_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Romania
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Romania_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Russian Federation
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Russian Federation_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Slovakia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Slovakia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Slovenia
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Slovenia_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Spain
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Spain_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Sweden
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Sweden_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Switzerland
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Switzerland_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Türkiye
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Türkiye_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Ukraine
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Ukraine_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: United Kingdom of Great Britain and Northern Ireland
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\United Kingdom of Great Britain and Northern Ireland_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: United States of America
# ➡ 세 번째 옵션: ....Total GHG emissions without LULUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\United States of America_Total GHG emissions without LULUCF_Mt CO2e.xlsx
#
# 🌐 국가 처리 중: Afghanistan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Afghanistan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Albania
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Albania_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Algeria
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Algeria_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Andorra
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ❌ 다운로드 버튼 클릭 실패
#
# 🌐 국가 처리 중: Angola
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Angola_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Antigua and Barbuda
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Antigua and Barbuda_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Argentina
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Argentina_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Armenia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Armenia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Azerbaijan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Azerbaijan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Bahamas
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bahamas_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Bahrain
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bahrain_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Bangladesh
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bangladesh_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Barbados
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Barbados_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Belize
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Belize_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Benin
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Benin_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Bhutan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bhutan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Bolivia (Plurinational State of)
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bolivia (Plurinational State of)_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Bosnia and Herzegovina
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Bosnia and Herzegovina_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Botswana
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Botswana_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Brazil
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Brazil_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Brunei Darussalam
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Brunei Darussalam_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Burkina Faso
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Burkina Faso_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Burundi
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Burundi_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Cabo Verde
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cabo Verde_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Cambodia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cambodia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Cameroon
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cameroon_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Central African Republic
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Central African Republic_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Chad
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Chad_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Chile
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Chile_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: China
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\China_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Colombia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Colombia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Comoros
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Comoros_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Congo
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Congo_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Cook Islands
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cook Islands_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Costa Rica
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Costa Rica_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Cote d'Ivoire
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cote d'Ivoire_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Cuba
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Cuba_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Democratic People's Republic of Korea
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Democratic People's Republic of Korea_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Democratic Republic of the Congo
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Democratic Republic of the Congo_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Djibouti
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Djibouti_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Dominica
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Dominica_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Dominican Republic
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Dominican Republic_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Ecuador
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Ecuador_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Egypt
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Egypt_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: El Salvador
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\El Salvador_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Equatorial Guinea
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ❌ 다운로드 버튼 클릭 실패
#
# 🌐 국가 처리 중: Eritrea
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Eritrea_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Eswatini
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Eswatini_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Ethiopia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Ethiopia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Fiji
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Fiji_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Gabon
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Gabon_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Gambia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Gambia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Georgia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Georgia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Ghana
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Ghana_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Grenada
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Grenada_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Guatemala
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Guatemala_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Guinea
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Guinea_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Guinea-Bissau
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Guinea-Bissau_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Guyana
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Guyana_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Haiti
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Haiti_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Honduras
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Honduras_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: India
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\India_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Indonesia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Indonesia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Iran (Islamic Republic of)
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Iran (Islamic Republic of)_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Iraq
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Iraq_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Israel
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Israel_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Jamaica
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Jamaica_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Jordan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Jordan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Kenya
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Kenya_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Kiribati
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Kiribati_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Kuwait
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Kuwait_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Kyrgyzstan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Kyrgyzstan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Lao People's Democratic Republic
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Lao People's Democratic Republic_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Lebanon
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Lebanon_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Lesotho
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Lesotho_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Liberia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Liberia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Libya
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ❌ 다운로드 버튼 클릭 실패
#
# 🌐 국가 처리 중: Madagascar
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Madagascar_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Malawi
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Malawi_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Malaysia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Malaysia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Maldives
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Maldives_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Mali
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Mali_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Marshall Islands
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Marshall Islands_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Mauritania
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Mauritania_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Mauritius
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Mauritius_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Mexico
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Mexico_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Micronesia (Federated States of)
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Micronesia (Federated States of)_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Mongolia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Mongolia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Montenegro
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Montenegro_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Morocco
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Morocco_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Mozambique
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Mozambique_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Myanmar
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Myanmar_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Namibia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Namibia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Nauru
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Nauru_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Nepal
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Nepal_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Nicaragua
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Nicaragua_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Niger
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Niger_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Nigeria
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Nigeria_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Niue
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Niue_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: North Macedonia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\North Macedonia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Oman
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Oman_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Pakistan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Pakistan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Palau
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Palau_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Panama
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Panama_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Papua New Guinea
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Papua New Guinea_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Paraguay
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Paraguay_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Peru
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Peru_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Philippines
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Philippines_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Qatar
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Qatar_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Republic of Korea
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Republic of Korea_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Republic of Moldova
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Republic of Moldova_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Rwanda
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Rwanda_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Saint Kitts and Nevis
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Saint Kitts and Nevis_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Saint Lucia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Saint Lucia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Saint Vincent and the Grenadines
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Saint Vincent and the Grenadines_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Samoa
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Samoa_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: San Marino
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\San Marino_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Sao Tome and Principe
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Sao Tome and Principe_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Saudi Arabia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Saudi Arabia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Senegal
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Senegal_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Serbia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Serbia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Seychelles
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Seychelles_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Sierra Leone
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ❌ 다운로드 버튼 클릭 실패
#
# 🌐 국가 처리 중: Singapore
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Singapore_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Solomon Islands
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Solomon Islands_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Somalia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ❌ 다운로드 버튼 클릭 실패
#
# 🌐 국가 처리 중: South Africa
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\South Africa_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: South Sudan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\South Sudan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Sri Lanka
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Sri Lanka_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: State of Palestine
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\State of Palestine_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Sudan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Sudan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Suriname
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Suriname_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Syrian Arab Republic
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Syrian Arab Republic_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Tajikistan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Tajikistan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Thailand
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Thailand_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Timor-Leste
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Timor-Leste_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Togo
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Togo_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Tonga
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Tonga_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Trinidad and Tobago
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Trinidad and Tobago_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Tunisia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Tunisia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Turkmenistan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Turkmenistan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Tuvalu
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Tuvalu_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Uganda
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Uganda_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: United Arab Emirates
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\United Arab Emirates_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: United Republic of Tanzania
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\United Republic of Tanzania_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Uruguay
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Uruguay_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Uzbekistan
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Uzbekistan_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Vanuatu
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Vanuatu_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Venezuela (Bolivarian Republic of)
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Venezuela (Bolivarian Republic of)_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Viet Nam
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Viet Nam_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Yemen
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Yemen_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Zambia
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Zambia_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# 🌐 국가 처리 중: Zimbabwe
# ➡ 세 번째 옵션: ....Total GHG emissions excluding LULUCF/LUCF
# ⬇️ 다운로드 시도
# 📁 저장 완료: C:\Users\박주현\Documents\UNSD total ghg data\Zimbabwe_Total GHG emissions excluding LULUCF_LUCF_Tg CO2e.xlsx
#
# ✅ 크롤링 완료

# %%
import os
import pandas as pd
import re
import glob

# 1. Year 칼럼을 가진 기본 데이터프레임 생성
years = list(range(1960, 2025))
main_df = pd.DataFrame({'Year': years})
main_df['Year'] = main_df['Year'].astype(str)  # 문자열 형변환

# 2. 대상 폴더 경로 설정
folder_path = r'C:\Users\박주현\Documents\GHG-Dashboard'
file_paths = glob.glob(os.path.join(folder_path, "*.xlsx"))

# 3. 국가별 데이터 추출 및 정제
country_dfs = []
for file_path in file_paths:
    try:
        df = pd.read_excel(file_path, header=None)

        # "Base year"이 3행에 포함된 열 제거
        df = df.loc[:, ~df.iloc[2].astype(str).str.contains('Base year', case=False)]

        # 필요한 행만 추출
        df_filtered = df[df.iloc[:, 0].isin([
            'Category',
            'Total GHG emissions without LULUCF',
            'Total GHG emissions excluding LULUCF/LUCF'
        ])]

        # 데이터 존재 여부 확인
        if df_filtered.shape[0] < 2:
            print(f"⚠️ 필요한 행이 부족함: {file_path}")
            continue

        # 4행 1열은 'Year', 5행 1열은 국가명으로 지정
        df_filtered.iloc[0, 0] = 'Year'
        country_name = os.path.basename(file_path).split('_')[0].strip()
        df_filtered.iloc[1, 0] = country_name

        # 전치 후 처리
        country_df = df_filtered.T
        country_df.columns = country_df.iloc[0]  # 첫 행을 컬럼명으로
        country_df = country_df.drop(index=0)    # 첫 행 제거

        # Year 값 정제 (4자리 숫자 추출)
        country_df['Year'] = country_df['Year'].apply(lambda x: ''.join(re.findall(r'\d', str(x))[:4]))
        country_df['Year'] = country_df['Year'].astype(str)

        country_dfs.append(country_df)

    except Exception as e:
        print(f"❌ 처리 오류: {file_path} - {e}")

# 4. 병합
final_df = main_df.copy()
for country_df in country_dfs:
    final_df = pd.merge(final_df, country_df, on='Year', how='left')

# 5. 저장
output_path = os.path.join(folder_path, "UNFCCC_GHG_merged.xlsx")
final_df.to_excel(output_path, index=False)
print(f"✅ 병합 파일 저장 완료: {output_path}")
# Out:
# ✅ 병합 파일 저장 완료: C:\Users\박주현\Documents\GHG-Dashboard\UNFCCC_GHG_merged.xlsx
